# %%
#Análisis Computacional de EDO's
#Estudiantes: Joao Taco, Luis Mejía
#Maestría en Economía del Desarrollo
#Universidad FLACSO

#Caso 1
#Vectores y valores propios y diferentes

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Función para actualizar la matriz y las gráficas
def update_matrix(a, b, c, d):
    A = np.array([[a, b], [c, d]])


# Función para actualizar la matriz y las gráficas
def update_matrix(a, b, c, d):
    A = np.array([[a, b], [c, d]])


# Definir la matriz A
A = np.array([[11, 5],
              [8, 7]])

# Calcular valores y vectores propios
eigenvalues, eigenvectors = np.linalg.eig(A)

# Mostrar valores propios
print("Valores propios:", eigenvalues)
print("Vectores propios:")
print(eigenvectors)

# Sistema de ecuaciones
def system(t, z):
    return A @ z  # Producto matricial para dx/dt y dy/dt

# Condiciones iniciales
z0 = [2, 6]

# Tiempo de simulación
t_span = (0, 2)
t_eval = np.linspace(*t_span, 100)

# Resolver sistema de ecuaciones
dyn = solve_ivp(system,t_span, z0, t_eval=t_eval)

# Gráfica temporal
plt.figure(figsize=(8, 5))
plt.plot(dyn.t, dyn.y[0], label='x(t)', color='b')

plt.xlabel('Tiempo')
plt.ylabel('x')
plt.legend()
plt.title('Gráfico de Xt')
plt.grid()
plt.show()

plt.figure(figsize=(8, 5))

plt.plot(dyn.t, dyn.y[1], label='y(t)', color='r')
plt.xlabel('Tiempo')
plt.ylabel('y')
plt.legend()
plt.title('Gráfico de Yt')
plt.grid()

import numpy as np
import matplotlib.pyplot as plt

# Definir la matriz A
A = np.array([[11, 5],
              [8, 7]])

# Calcular valores y vectores propios
eigenvalues, eigenvectors = np.linalg.eig(A)

# Crear una malla de puntos en el plano
x_vals = np.linspace(-10, 10, 20)
y_vals = np.linspace(-10, 10, 20)
X, Y = np.meshgrid(x_vals, y_vals)

# Calcular el campo vectorial en cada punto
DX = A[0, 0] * X + A[0, 1] * Y
DY = A[1, 0] * X + A[1, 1] * Y

# Crear la figura
plt.figure(figsize=(8, 8))
plt.streamplot(X, Y, DX, DY, color='black', linewidth=1, arrowsize=1)

# Dibujar eigenvectores
for i in range(2):
    vec = eigenvectors[:, i]
    plt.plot([-10 * vec[0], 10 * vec[0]], [-10 * vec[1], 10 * vec[1]], 
             linestyle='dashed', linewidth=2, color=('r' if i == 0 else 'b'))

# Ajustes de la gráfica
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Diagrama de Fase con Eigenvectores")
plt.grid()
plt.legend()
# Mostrar la gráfica
plt.show()
# Out:
# Valores propios: [15.63324958  2.36675042]
# Vectores propios:
# [[ 0.73349588 -0.50117161]
#  [ 0.6796939   0.86534792]]
# C:\Users\User\AppData\Local\Temp\ipykernel_1440\3641081249.py:99: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Caso 2
#Valores y valores propios e iguales

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Definir la matriz B con valores propios repetidos
B = np.array([[2,-1],
              [1, 0]])

# Calcular valores y vectores propios
eigenvalues, eigenvectors = np.linalg.eig(B)

# Mostrar valores propios
print("Valores propios:", eigenvalues)
print("Vectores propios:")
print(eigenvectors)

# Sistema de ecuaciones
def system(t, z):
    return B @ z  # Producto matricial para dx/dt y dy/dt

# Condiciones iniciales
z0 = [4, 11]

# Tiempo de simulación
t_span = (0, 2)
t_eval = np.linspace(*t_span, 100)

# Resolver sistema de ecuaciones
dyn = solve_ivp(system, t_span, z0, t_eval=t_eval)

# Gráfica temporal
plt.figure(figsize=(8, 5))
plt.plot(dyn.t, dyn.y[0], label='x(t)', color='b')
plt.xlabel('Tiempo')
plt.ylabel('x')
plt.legend()
plt.title('Gráfica Xt')
plt.grid()

plt.show()

plt.plot(dyn.t, dyn.y[1], label='y(t)', color='r')
plt.xlabel('Tiempo')
plt.ylabel('y')
plt.legend()
plt.title('Gráfica Yt')
plt.grid()

plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eig

# Definir la matriz B
B = np.array([[2,-1],
              [1, 0]])

# Calcular autovalores y autovectores
autovalores, autovectores = eig(B)

# Verificar si hay valores propios repetidos
if len(np.unique(autovalores)) < len(autovalores):
    print("La matriz tiene valores propios repetidos. Se usará la forma de Jordan.")

    # Calcular la forma de Jordan manualmente
    # Para una matriz 2x2 con un valor propio repetido, la forma de Jordan es:
    J = np.array([[autovalores[0], 1],
                  [0, autovalores[0]]])

    # La matriz de transformación P se construye con el autovector y el vector propio generalizado
    # Para B = [[3, 1], [0, 3]], el autovector es [1, 0] y el vector propio generalizado es [0, 1]
    P = np.array([[1, 0],
                  [0, 1]])

    # Inversa de P
    P_inv = np.linalg.inv(P)
else:
    print("La matriz no tiene valores propios repetidos.")
    J = np.diag(autovalores)  # Forma diagonal
    P = autovectores
    P_inv = np.linalg.inv(P)

# Crear una malla de puntos en el plano
x_vals = np.linspace(-10, 10, 20)
y_vals = np.linspace(-10, 10, 20)
X, Y = np.meshgrid(x_vals, y_vals)

# Calcular el campo vectorial en cada punto
DX = B[0, 0] * X + B[0, 1] * Y
DY = B[1, 0] * X + B[1, 1] * Y

# Crear la figura
plt.figure(figsize=(8, 8))
plt.streamplot(X, Y, DX, DY, color='black', linewidth=1, arrowsize=1)

# Dibujar eigenvectores
for i in range(2):
    vec = P[:, i]
    plt.plot([-10 * vec[0], 10 * vec[0]], [-10 * vec[1], 10 * vec[1]], 
             linestyle='dashed', linewidth=2, color=('r' if i == 0 else 'b'))

# Ajustes de la gráfica
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Diagrama de Fase con Eigenvectores (Forma de Jordan)")
plt.grid()

# Mostrar la gráfica
plt.show()
# Out:
# Valores propios: [1.+6.68896751e-09j 1.-6.68896751e-09j]
# Vectores propios:
# [[0.70710678+4.72981429e-09j 0.70710678-4.72981429e-09j]
#  [0.70710678+0.00000000e+00j 0.70710678-0.00000000e+00j]]
# La matriz no tiene valores propios repetidos.

# %%
#Caso 3
#Vectores y valores propios y complejos

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Definir la matriz C con valores propios complejos
C = np.array([[11, -5],
              [35, 4]])

# Calcular valores y vectores propios
eigenvalues, eigenvectors = np.linalg.eig(C)

# Mostrar valores propios
print("Valores propios:", eigenvalues)
print("Vectores propios:")
print(eigenvectors)

# Sistema de ecuaciones
def system(t, z):
    return C @ z  # Producto matricial para dx/dt y dy/dt

# Condiciones iniciales
z0 = [11, 4]

# Tiempo de simulación
t_span = (0, 2)
t_eval = np.linspace(*t_span, 200)

# Resolver sistema de ecuaciones
dyn = solve_ivp(system, t_span, z0, t_eval=t_eval)

# Gráfica temporal
plt.figure(figsize=(8, 5))
plt.plot(dyn.t, dyn.y[0], label='x(t)', color='b')
plt.xlabel('Tiempo')
plt.ylabel('x')
plt.legend()
plt.title('Gráfica Xt')
plt.grid()

plt.show()

plt.plot(dyn.t, dyn.y[1], label='y(t)', color='r')
plt.xlabel('Tiempo')
plt.ylabel('y')
plt.legend()
plt.title('Gráfica Yt')
plt.grid()

plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Definir la matriz C con valores propios complejos
C = np.array([[11, -5],
              [35, 4]])

# Calcular valores y vectores propios
eigenvalues, eigenvectors = np.linalg.eig(C)

# Mostrar valores propios
print("Valores propios:", eigenvalues)
print("Vectores propios:")
print(eigenvectors)

# Sistema de ecuaciones
def system(t, z):
    return C @ z  # Producto matricial para dx/dt y dy/dt

# Condiciones iniciales
z0 = [11, 4]

# Tiempo de simulación
t_span = (0, 2)
t_eval = np.linspace(*t_span, 200)

# Resolver sistema de ecuaciones
dyn = solve_ivp(system, t_span, z0, t_eval=t_eval)

# Crear el diagrama de fase
x_vals = np.linspace(-2, 2, 20)
y_vals = np.linspace(-2, 2, 20)
X, Y = np.meshgrid(x_vals, y_vals)
U, V = C @ np.array([X.ravel(), Y.ravel()])
U = U.reshape(X.shape)
V = V.reshape(Y.shape)

plt.figure(figsize=(8, 6))
plt.streamplot(X, Y, U, V, color='black', linewidth=0.8, density=1)
plt.plot(dyn.y[0], dyn.y[1], color='g', label='Trayectoria')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Trayectoria')
plt.legend()
plt.grid()
plt.show()

# Definir la matriz A
C = np.array([[11, -5],
              [35, 4]])

# Crear una malla de puntos en el plano
x_vals = np.linspace(-10, 10, 20)
y_vals = np.linspace(-10, 10, 20)
X, Y = np.meshgrid(x_vals, y_vals)

# Calcular el campo vectorial en cada punto
DX = C[0, 0] * X + C[0, 1] * Y
DY = C[1, 0] * X + C[1, 1] * Y

# Crear la figura
plt.figure(figsize=(8, 8))
plt.streamplot(X, Y, DX, DY, color='black', linewidth=1, arrowsize=1)

# Ajustes de la gráfica
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Diagrama de Fase con Eigenvectores")
plt.grid()
plt.legend()
# Mostrar la gráfica
plt.show()
# Out:
# Valores propios: [7.5+12.75735082j 7.5-12.75735082j]
# Vectores propios:
# [[0.09354143+0.34095454j 0.09354143-0.34095454j]
#  [0.93541435+0.j         0.93541435-0.j        ]]
# Valores propios: [7.5+12.75735082j 7.5-12.75735082j]
# Vectores propios:
# [[0.09354143+0.34095454j 0.09354143-0.34095454j]
#  [0.93541435+0.j         0.93541435-0.j        ]]
# C:\Users\User\AppData\Local\Temp\ipykernel_14956\837857508.py:127: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
